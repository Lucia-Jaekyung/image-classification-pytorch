# %% [markdown]
# # AlexNet

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
import tensorflow_datasets as tfds

import keras
from keras.models import Model
from keras.layers import Conv2D, Dropout, MaxPool2D, Dense, Flatten, Input
from tensorflow.nn import local_response_normalization as LRN

# %% [markdown]
# ## 데이터셋 불러오기

# %%
train_ds, ds_info = tfds.load('imagenette', split='train', with_info=True)
val_ds = tfds.load('imagenette', split='validation', with_info=False)

print(train_ds)
print(val_ds)
# Out:
# <PrefetchDataset element_spec={'image': TensorSpec(shape=(None, None, 3), dtype=tf.uint8, name=None), 'label': TensorSpec(shape=(), dtype=tf.int64, name=None)}>
# <PrefetchDataset element_spec={'image': TensorSpec(shape=(None, None, 3), dtype=tf.uint8, name=None), 'label': TensorSpec(shape=(), dtype=tf.int64, name=None)}>

# %%
fig = tfds.show_examples(train_ds, ds_info)

# %%
ds_info
# Out:
# tfds.core.DatasetInfo(
#     name='imagenette',
#     full_name='imagenette/full-size-v2/1.0.0',
#     description="""
#     Imagenette is a subset of 10 easily classified classes from the Imagenet
#     dataset. It was originally prepared by Jeremy Howard of FastAI. The objective
#     behind putting together a small version of the Imagenet dataset was mainly
#     because running new ideas/algorithms/experiments on the whole Imagenet take a
#     lot of time.
#
#     This version of the dataset allows researchers/practitioners to quickly try out
#     ideas and share with others. The dataset comes in three variants:
#
#     *   Full size
#     *   320 px
#     *   160 px
#
#     Note: The v2 config correspond to the new 70/30 train/valid split (released in
#     Dec 6 2019).
#     """,
#     config_description="""
#     full-size variant.
#     """,
#     homepage='https://github.com/fastai/imagenette',
#     data_path='/root/tensorflow_datasets/imagenette/full-size-v2/1.0.0',
#     file_format=tfrecord,
#     download_size=1.45 GiB,
#     dataset_size=1.46 GiB,
#     features=FeaturesDict({
#         'image': Image(shape=(None, None, 3), dtype=uint8),
#         'label': ClassLabel(shape=(), dtype=int64, num_classes=10),
#     }),
#     supervised_keys=('image', 'label'),
#     disable_shuffling=False,
#     splits={
#         'train': <SplitInfo num_examples=9469, num_shards=16>,
#         'validation': <SplitInfo num_examples=3925, num_shards=4>,
#     },
#     citation="""@misc{imagenette,
#       author    = "Jeremy Howard",
#       title     = "imagenette",
#       url       = "https://github.com/fastai/imagenette/"
#     }""",
# )

# %%
# label을 출력합니다
ds_info.features["label"].names
# Out:
# ['n01440764',
#  'n02102040',
#  'n02979186',
#  'n03000684',
#  'n03028079',
#  'n03394916',
#  'n03417042',
#  'n03425413',
#  'n03445777',
#  'n03888257']

# %%
# Number of classes: 10
num_classes = ds_info.features['label'].num_classes
print("num_classes: ", num_classes)

# Number of images: train 9469 / validation 3925
num_train_imgs = ds_info.splits['train'].num_examples
num_val_imgs = ds_info.splits['validation'].num_examples
print("num_train_imgs: ", num_train_imgs)
print("num_val_imgs: ", num_val_imgs)
# Out:
# num_classes:  10
# num_train_imgs:  9469
# num_val_imgs:  3925

# %%
import math
import functools

input_shape = [227, 227, 3]
batch_size = 128
num_epochs = 90

def _prepare_data_fn(features, input_shape, augment=False):
    """
    Resize image to expected dimensions, and opt. apply some random transformations.
    이미지 resizing, augmentation 등을 수행합니다.
    
    - features: Data
    - input_shape: Shape expected by the models (images will be resized accordingly)
    - augment: Flag to apply some random augmentations to the images
    - return: Augmented Images, Labels
    """
    input_shape = tf.convert_to_tensor(input_shape)

    # Tensorflow-dataset returns batches as feature dictionaries, expected by Estimators. 
    # To train Keras models, it is more straightforward to return the batch content as tuples. 

    image = features['image']
    label = features['label']

    # 이미지 픽셀 값의 범위를 [0, 255]에서 [0, 1.]로 normalize 합니다.
    image = tf.image.convert_image_dtype(image, tf.float32)

    if augment:

        # 무작위 좌우대칭
        image = tf.image.random_flip_left_right(image)

        # 무작위 밝기/포화도 변화
        image = tf.image.random_brightness(image, max_delta=0.1)
        image = tf.image.random_saturation(image, lower=0.5, upper=1.5)
        image = tf.clip_by_value(image, 0.0, 1.0) # 픽셀 값이 범위 밖으로 넘어가지 않게 확인
        image = tf.image.resize(image, input_shape[:2])

        
    else:
        image = tf.image.resize(image, input_shape[:2])

    return image, label




prepare_data_fn_for_train = functools.partial(_prepare_data_fn, 
                                              input_shape=input_shape,
                                              augment=True)

train_ds = train_ds.repeat(num_epochs).shuffle(2023)

train_ds = train_ds.map(prepare_data_fn_for_train, num_parallel_calls=4)
train_ds = train_ds.batch(batch_size)
train_ds = train_ds.prefetch(1)


# # 배치 크기 적용
# train_ds = train_ds.batch(batch_size)
# train_ds = train_ds.prefetch(1)


# validation dataset (섞거나 증강시키지 않음)
prepare_data_fn_for_val = functools.partial(_prepare_data_fn,
                                           input_shape=input_shape,
                                           augment=False)


val_ds = (val_ds.repeat().map(prepare_data_fn_for_val, num_parallel_calls=4)
                         .batch(batch_size)
                         .prefetch(1))


train_steps_per_epoch = math.ceil(num_train_imgs / batch_size)
val_steps_per_epoch = math.ceil(num_val_imgs / batch_size)

# %%
for image_batch, labels_batch in train_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (128, 227, 227, 3)
# (128,)

# %%
for image_batch, labels_batch in val_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (128, 227, 227, 3)
# (128,)

# %% [markdown]
# ## 모델
# ### 구조
# - Input: 227 * 227 * 3,
# - Conv2D 5층
#     - 필터 수 96, 크기 11 * 11, stride 4
#         - LRN(k = 2, n = 5, α = 10^(−4), and β = 0.75)
#         - pool(stride = 2, filter size = 3)
#     - 필터 수 256, 크기 5 * 5
#         - LRN(k = 2, n = 5, α = 10^(−4), and β = 0.75)
#         - pool(stride = 2, filter size = 3)
#     - 필터 수 384, 크기 3 * 3
#     - 필터 수 384, 크기 5 * 5
#     - 필터 수 256, 크기 5 * 5
# - FCN 3층
#     - 4096, dropout(0.5)
#     - 4096, dropout(0.5)
#     - 10
# - weight initialization(N~(0, 0.01)): 2, 4, 5번 conv & FCN

# %%
inputs = Input(shape=(227, 227, 3))

# Conv 1
conv1 = Conv2D(96, (11, 11), 
               strides=4, 
               activation='relu')(inputs)
lrn1 = LRN(conv1, bias=2, depth_radius=5, alpha=0.0001, beta= 0.75)
pool1 = MaxPool2D((3, 3), 2)(lrn1)

# Conv 2
conv2 = Conv2D(256, (5, 5), 
               strides=1, 
               activation='relu', 
               padding='same',
               kernel_initializer=tf.random_normal_initializer(mean=0.0, stddev=0.01))(pool1)
lrn2 = LRN(conv2, bias=2, depth_radius=5, alpha=0.0001, beta= 0.75)
pool2 = MaxPool2D((3, 3), 2)(lrn2)

# Conv 3
conv3 = Conv2D(384, (3, 3), 
               strides=1, 
               activation='relu',
               padding='same')(pool2)

# Conv 4
conv4 = Conv2D(384, (5, 5), 
               strides=1, 
               activation='relu',
               padding='same')(conv3)

# Conv 5
conv5 = Conv2D(256, (5, 5), 
               strides=1, 
               activation='relu',
               padding='same')(conv4)
pool3 = MaxPool2D((3, 3), 2)(conv5)

# FCN 1
flat = Flatten()(pool3)
fcn1 = Dense(4096, activation='relu',
             kernel_initializer=tf.random_normal_initializer(mean=0.0, stddev=0.01))(flat)
drop1 = Dropout(0.5)(fcn1)

# FCN 2
fcn2 = Dense(4096, activation='relu',
             kernel_initializer=tf.random_normal_initializer(mean=0.0, stddev=0.01))(drop1)
drop2 = Dropout(0.5)(fcn2)

# FCN 3
fcn3 = Dense(10, activation='softmax')(drop2)

model = Model(inputs=inputs, outputs=fcn3, name='alexnet')

# %%
model.summary()
# Out:
# Model: "alexnet"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 227, 227, 3)]     0
#
#  conv2d (Conv2D)             (None, 55, 55, 96)        34944
#
#  tf.nn.local_response_normal  (None, 55, 55, 96)       0
#  ization (TFOpLambda)
#
#  max_pooling2d (MaxPooling2D  (None, 27, 27, 96)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 27, 27, 256)       614656
#
#  tf.nn.local_response_normal  (None, 27, 27, 256)      0
#  ization_1 (TFOpLambda)
#
#  max_pooling2d_1 (MaxPooling  (None, 13, 13, 256)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 13, 13, 384)       885120
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 384)       3686784
#
#  conv2d_4 (Conv2D)           (None, 13, 13, 256)       2457856
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 4096)              37752832
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 10)                40970
#
# =================================================================
# Total params: 62,254,474
# Trainable params: 62,254,474
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 훈련
# - Optimizer: SGD
# - Loss:
# - Epochs: 90 -> 70
# - batch size = 128
# - momentum = 0.9
# - weight decay = 0.0005
# - epochs 90
# - lr = 0.01
# - reduce lr on plateau: 3회, 0.1배

# %%
optimizer = keras.optimizers.SGD(learning_rate=0.01, momentum=0.9, decay=0.0005, nesterov=False)
loss_fn = 'sparse_categorical_crossentropy'
reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1,
                              patience=4, min_lr=0.0001)

# %%
model.compile(optimizer=optimizer,
              loss=loss_fn,
              metrics=['accuracy'])

# %%
hist = model.fit(train_ds,
                 epochs=num_epochs,
                 steps_per_epoch=train_steps_per_epoch,
                 validation_steps=val_steps_per_epoch,
                 verbose=1,
                 callbacks=[reduce_lr],
                 validation_data=val_ds)
# Out:
# Epoch 1/90
# 74/74 [==============================] - 89s 1s/step - loss: 2.3018 - accuracy: 0.1096 - val_loss: 2.3016 - val_accuracy: 0.0910 - lr: 0.0100
# Epoch 2/90
# 74/74 [==============================] - 74s 1s/step - loss: 2.2937 - accuracy: 0.1372 - val_loss: 2.2589 - val_accuracy: 0.1744 - lr: 0.0100
# Epoch 3/90
# 74/74 [==============================] - 75s 1s/step - loss: 2.2721 - accuracy: 0.1437 - val_loss: 2.2509 - val_accuracy: 0.1353 - lr: 0.0100
# Epoch 4/90
# 74/74 [==============================] - 74s 1s/step - loss: 2.2035 - accuracy: 0.2049 - val_loss: 2.1648 - val_accuracy: 0.2230 - lr: 0.0100
# Epoch 5/90
# 74/74 [==============================] - 75s 1s/step - loss: 2.1393 - accuracy: 0.2394 - val_loss: 2.0804 - val_accuracy: 0.2676 - lr: 0.0100
# Epoch 6/90
# 74/74 [==============================] - 74s 1s/step - loss: 2.0056 - accuracy: 0.2826 - val_loss: 1.9217 - val_accuracy: 0.3175 - lr: 0.0100
# Epoch 7/90
# 74/74 [==============================] - 75s 1s/step - loss: 1.8746 - accuracy: 0.3471 - val_loss: 1.7920 - val_accuracy: 0.3853 - lr: 0.0100
# Epoch 8/90
# 74/74 [==============================] - 74s 1s/step - loss: 1.7381 - accuracy: 0.3960 - val_loss: 1.6960 - val_accuracy: 0.4128 - lr: 0.0100
# Epoch 9/90
# 74/74 [==============================] - 74s 1s/step - loss: 1.6521 - accuracy: 0.4351 - val_loss: 1.5744 - val_accuracy: 0.4690 - lr: 0.0100
# Epoch 10/90
# 74/74 [==============================] - 74s 1s/step - loss: 1.5465 - accuracy: 0.4672 - val_loss: 1.5386 - val_accuracy: 0.4783 - lr: 0.0100
# Epoch 11/90
# 74/74 [==============================] - 74s 1s/step - loss: 1.4499 - accuracy: 0.5075 - val_loss: 1.3340 - val_accuracy: 0.5559 - lr: 0.0100
# Epoch 12/90
# 74/74 [==============================] - 74s 1s/step - loss: 1.3380 - accuracy: 0.5603 - val_loss: 1.2973 - val_accuracy: 0.5716 - lr: 0.0100
# Epoch 13/90
# 74/74 [==============================] - 74s 1s/step - loss: 1.2414 - accuracy: 0.5887 - val_loss: 1.1963 - val_accuracy: 0.6089 - lr: 0.0100
# Epoch 14/90
# 74/74 [==============================] - 73s 988ms/step - loss: 1.1796 - accuracy: 0.6095 - val_loss: 1.1795 - val_accuracy: 0.6137 - lr: 0.0100
# Epoch 15/90
# 74/74 [==============================] - 74s 1s/step - loss: 1.0990 - accuracy: 0.6376 - val_loss: 1.1709 - val_accuracy: 0.6134 - lr: 0.0100
# Epoch 16/90
# 74/74 [==============================] - 72s 983ms/step - loss: 1.0532 - accuracy: 0.6508 - val_loss: 1.0964 - val_accuracy: 0.6399 - lr: 0.0100
# Epoch 17/90
# 74/74 [==============================] - 73s 1000ms/step - loss: 0.9991 - accuracy: 0.6716 - val_loss: 1.0479 - val_accuracy: 0.6562 - lr: 0.0100
# Epoch 18/90
# 74/74 [==============================] - 72s 979ms/step - loss: 0.9315 - accuracy: 0.6932 - val_loss: 1.0081 - val_accuracy: 0.6767 - lr: 0.0100
# Epoch 19/90
# 74/74 [==============================] - 73s 991ms/step - loss: 0.8932 - accuracy: 0.7078 - val_loss: 0.9632 - val_accuracy: 0.6822 - lr: 0.0100
# Epoch 20/90
# 74/74 [==============================] - 73s 998ms/step - loss: 0.8536 - accuracy: 0.7173 - val_loss: 1.0274 - val_accuracy: 0.6638 - lr: 0.0100
# Epoch 21/90
# 74/74 [==============================] - 74s 1s/step - loss: 0.7993 - accuracy: 0.7359 - val_loss: 0.8771 - val_accuracy: 0.7185 - lr: 0.0100
# Epoch 22/90
# 74/74 [==============================] - 72s 982ms/step - loss: 0.7309 - accuracy: 0.7575 - val_loss: 0.8719 - val_accuracy: 0.7223 - lr: 0.0100
# Epoch 23/90
# 74/74 [==============================] - 73s 1s/step - loss: 0.7107 - accuracy: 0.7626 - val_loss: 0.8516 - val_accuracy: 0.7233 - lr: 0.0100
# Epoch 24/90
# 74/74 [==============================] - 72s 986ms/step - loss: 0.6818 - accuracy: 0.7724 - val_loss: 0.8259 - val_accuracy: 0.7387 - lr: 0.0100
# Epoch 25/90
# 74/74 [==============================] - 73s 994ms/step - loss: 0.6284 - accuracy: 0.7916 - val_loss: 0.8454 - val_accuracy: 0.7349 - lr: 0.0100
# Epoch 26/90
# 74/74 [==============================] - 73s 990ms/step - loss: 0.5907 - accuracy: 0.8038 - val_loss: 0.8576 - val_accuracy: 0.7213 - lr: 0.0100
# Epoch 27/90
# 74/74 [==============================] - 73s 995ms/step - loss: 0.5632 - accuracy: 0.8111 - val_loss: 0.8608 - val_accuracy: 0.7351 - lr: 0.0100
# Epoch 28/90
# 74/74 [==============================] - 72s 985ms/step - loss: 0.5398 - accuracy: 0.8233 - val_loss: 0.7846 - val_accuracy: 0.7555 - lr: 0.0100
# Epoch 29/90
# 74/74 [==============================] - 74s 1s/step - loss: 0.4884 - accuracy: 0.8337 - val_loss: 0.8387 - val_accuracy: 0.7497 - lr: 0.0100
# Epoch 30/90
# 74/74 [==============================] - 72s 978ms/step - loss: 0.4515 - accuracy: 0.8497 - val_loss: 0.8143 - val_accuracy: 0.7452 - lr: 0.0100
# Epoch 31/90
# 74/74 [==============================] - 74s 1s/step - loss: 0.4076 - accuracy: 0.8622 - val_loss: 0.8757 - val_accuracy: 0.7447 - lr: 0.0100
# Epoch 32/90
# 74/74 [==============================] - 72s 980ms/step - loss: 0.4104 - accuracy: 0.8641 - val_loss: 0.8470 - val_accuracy: 0.7573 - lr: 0.0100
# Epoch 33/90
# 74/74 [==============================] - 74s 1s/step - loss: 0.3485 - accuracy: 0.8877 - val_loss: 0.8185 - val_accuracy: 0.7704 - lr: 1.0000e-03
# Epoch 34/90
# 74/74 [==============================] - 72s 983ms/step - loss: 0.2723 - accuracy: 0.9116 - val_loss: 0.8239 - val_accuracy: 0.7732 - lr: 1.0000e-03
# Epoch 35/90
# 74/74 [==============================] - 74s 1s/step - loss: 0.2570 - accuracy: 0.9164 - val_loss: 0.8345 - val_accuracy: 0.7752 - lr: 1.0000e-03
# Epoch 36/90
# 74/74 [==============================] - 72s 981ms/step - loss: 0.2459 - accuracy: 0.9225 - val_loss: 0.8453 - val_accuracy: 0.7732 - lr: 1.0000e-03
# Epoch 37/90
# 74/74 [==============================] - 74s 1s/step - loss: 0.2373 - accuracy: 0.9226 - val_loss: 0.8306 - val_accuracy: 0.7747 - lr: 1.0000e-04
# Epoch 38/90
# 74/74 [==============================] - 72s 986ms/step - loss: 0.2338 - accuracy: 0.9243 - val_loss: 0.8373 - val_accuracy: 0.7755 - lr: 1.0000e-04
# Epoch 39/90
# 74/74 [==============================] - 74s 1s/step - loss: 0.2327 - accuracy: 0.9264 - val_loss: 0.8346 - val_accuracy: 0.7742 - lr: 1.0000e-04
# Epoch 40/90
# 74/74 [==============================] - 72s 987ms/step - loss: 0.2223 - accuracy: 0.9293 - val_loss: 0.8397 - val_accuracy: 0.7749 - lr: 1.0000e-04
# Epoch 41/90
# 74/74 [==============================] - 73s 990ms/step - loss: 0.2272 - accuracy: 0.9267 - val_loss: 0.8405 - val_accuracy: 0.7747 - lr: 1.0000e-04
# Epoch 42/90
# 74/74 [==============================] - 74s 1s/step - loss: 0.2238 - accuracy: 0.9327 - val_loss: 0.8389 - val_accuracy: 0.7744 - lr: 1.0000e-04
# Epoch 43/90
# 74/74 [==============================] - 72s 986ms/step - loss: 0.2211 - accuracy: 0.9315 - val_loss: 0.8415 - val_accuracy: 0.7749 - lr: 1.0000e-04
# Epoch 44/90
# 74/74 [==============================] - 74s 1s/step - loss: 0.2227 - accuracy: 0.9280 - val_loss: 0.8423 - val_accuracy: 0.7742 - lr: 1.0000e-04
# Epoch 45/90
# 74/74 [==============================] - 73s 990ms/step - loss: 0.2240 - accuracy: 0.9283 - val_loss: 0.8439 - val_accuracy: 0.7760 - lr: 1.0000e-04
# Epoch 46/90
# 74/74 [==============================] - 73s 997ms/step - loss: 0.2254 - accuracy: 0.9288 - val_loss: 0.8435 - val_accuracy: 0.7747 - lr: 1.0000e-04
# Epoch 47/90
# 74/74 [==============================] - 72s 981ms/step - loss: 0.2235 - accuracy: 0.9284 - val_loss: 0.8458 - val_accuracy: 0.7737 - lr: 1.0000e-04
# Epoch 48/90
# 74/74 [==============================] - 73s 1s/step - loss: 0.2271 - accuracy: 0.9288 - val_loss: 0.8429 - val_accuracy: 0.7747 - lr: 1.0000e-04
# Epoch 49/90
# 74/74 [==============================] - 73s 995ms/step - loss: 0.2154 - accuracy: 0.9333 - val_loss: 0.8473 - val_accuracy: 0.7744 - lr: 1.0000e-04
# Epoch 50/90
# 74/74 [==============================] - 73s 1s/step - loss: 0.2181 - accuracy: 0.9302 - val_loss: 0.8464 - val_accuracy: 0.7747 - lr: 1.0000e-04
# Epoch 51/90
# 74/74 [==============================] - 73s 998ms/step - loss: 0.2246 - accuracy: 0.9262 - val_loss: 0.8463 - val_accuracy: 0.7755 - lr: 1.0000e-04
# Epoch 52/90
# 74/74 [==============================] - 73s 996ms/step - loss: 0.2195 - accuracy: 0.9300 - val_loss: 0.8467 - val_accuracy: 0.7747 - lr: 1.0000e-04
# Epoch 53/90
# 74/74 [==============================] - 74s 1s/step - loss: 0.2235 - accuracy: 0.9304 - val_loss: 0.8470 - val_accuracy: 0.7760 - lr: 1.0000e-04
# Epoch 54/90
# 74/74 [==============================] - 74s 1s/step - loss: 0.2147 - accuracy: 0.9307 - val_loss: 0.8507 - val_accuracy: 0.7752 - lr: 1.0000e-04
# Epoch 55/90
# 74/74 [==============================] - 73s 993ms/step - loss: 0.2180 - accuracy: 0.9313 - val_loss: 0.8500 - val_accuracy: 0.7752 - lr: 1.0000e-04
# Epoch 56/90
# 74/74 [==============================] - 74s 1s/step - loss: 0.2153 - accuracy: 0.9325 - val_loss: 0.8518 - val_accuracy: 0.7742 - lr: 1.0000e-04
# Epoch 57/90
# 74/74 [==============================] - 73s 992ms/step - loss: 0.2138 - accuracy: 0.9320 - val_loss: 0.8515 - val_accuracy: 0.7752 - lr: 1.0000e-04
# Epoch 58/90
# 74/74 [==============================] - 73s 992ms/step - loss: 0.2130 - accuracy: 0.9331 - val_loss: 0.8529 - val_accuracy: 0.7760 - lr: 1.0000e-04
# Epoch 59/90
# 74/74 [==============================] - 74s 1s/step - loss: 0.2110 - accuracy: 0.9320 - val_loss: 0.8550 - val_accuracy: 0.7747 - lr: 1.0000e-04
# Epoch 60/90
# 74/74 [==============================] - 73s 989ms/step - loss: 0.2125 - accuracy: 0.9329 - val_loss: 0.8573 - val_accuracy: 0.7752 - lr: 1.0000e-04
# Epoch 61/90
# 74/74 [==============================] - 74s 1s/step - loss: 0.2208 - accuracy: 0.9281 - val_loss: 0.8525 - val_accuracy: 0.7757 - lr: 1.0000e-04
# Epoch 62/90
# 74/74 [==============================] - 73s 992ms/step - loss: 0.2094 - accuracy: 0.9330 - val_loss: 0.8544 - val_accuracy: 0.7767 - lr: 1.0000e-04
# Epoch 63/90
# 74/74 [==============================] - 74s 1s/step - loss: 0.2145 - accuracy: 0.9317 - val_loss: 0.8531 - val_accuracy: 0.7760 - lr: 1.0000e-04
# Epoch 64/90
# 74/74 [==============================] - 73s 997ms/step - loss: 0.2144 - accuracy: 0.9338 - val_loss: 0.8554 - val_accuracy: 0.7755 - lr: 1.0000e-04
# Epoch 65/90
# 74/74 [==============================] - 74s 1s/step - loss: 0.2151 - accuracy: 0.9317 - val_loss: 0.8575 - val_accuracy: 0.7760 - lr: 1.0000e-04
# Epoch 66/90
# 74/74 [==============================] - 73s 992ms/step - loss: 0.2103 - accuracy: 0.9358 - val_loss: 0.8565 - val_accuracy: 0.7762 - lr: 1.0000e-04
# Epoch 67/90
# 74/74 [==============================] - 74s 1s/step - loss: 0.2079 - accuracy: 0.9332 - val_loss: 0.8562 - val_accuracy: 0.7752 - lr: 1.0000e-04
# Epoch 68/90
# 74/74 [==============================] - 72s 984ms/step - loss: 0.2023 - accuracy: 0.9342 - val_loss: 0.8579 - val_accuracy: 0.7752 - lr: 1.0000e-04
# Epoch 69/90
# 74/74 [==============================] - 74s 1s/step - loss: 0.2062 - accuracy: 0.9331 - val_loss: 0.8598 - val_accuracy: 0.7749 - lr: 1.0000e-04
# Epoch 70/90
# 74/74 [==============================] - 74s 1s/step - loss: 0.2110 - accuracy: 0.9326 - val_loss: 0.8586 - val_accuracy: 0.7757 - lr: 1.0000e-04
# Epoch 71/90
# 74/74 [==============================] - 74s 1s/step - loss: 0.2063 - accuracy: 0.9340 - val_loss: 0.8591 - val_accuracy: 0.7755 - lr: 1.0000e-04
# Epoch 72/90
# 74/74 [==============================] - 73s 993ms/step - loss: 0.2076 - accuracy: 0.9338 - val_loss: 0.8596 - val_accuracy: 0.7747 - lr: 1.0000e-04
# Epoch 73/90
# 74/74 [==============================] - 75s 1s/step - loss: 0.2045 - accuracy: 0.9356 - val_loss: 0.8594 - val_accuracy: 0.7767 - lr: 1.0000e-04
# Epoch 74/90
# 74/74 [==============================] - 73s 994ms/step - loss: 0.2019 - accuracy: 0.9360 - val_loss: 0.8633 - val_accuracy: 0.7770 - lr: 1.0000e-04
# Epoch 75/90
# 74/74 [==============================] - 74s 1s/step - loss: 0.2119 - accuracy: 0.9333 - val_loss: 0.8617 - val_accuracy: 0.7765 - lr: 1.0000e-04
# Epoch 76/90
# 74/74 [==============================] - 74s 1s/step - loss: 0.2027 - accuracy: 0.9353 - val_loss: 0.8606 - val_accuracy: 0.7765 - lr: 1.0000e-04
# Epoch 77/90
# 74/74 [==============================] - 74s 1s/step - loss: 0.2106 - accuracy: 0.9330 - val_loss: 0.8603 - val_accuracy: 0.7762 - lr: 1.0000e-04
# Epoch 78/90
# 74/74 [==============================] - 75s 1s/step - loss: 0.2064 - accuracy: 0.9335 - val_loss: 0.8591 - val_accuracy: 0.7770 - lr: 1.0000e-04
# Epoch 79/90
# 74/74 [==============================] - 74s 1s/step - loss: 0.2045 - accuracy: 0.9356 - val_loss: 0.8615 - val_accuracy: 0.7755 - lr: 1.0000e-04
# Epoch 80/90
# 74/74 [==============================] - 75s 1s/step - loss: 0.2028 - accuracy: 0.9334 - val_loss: 0.8625 - val_accuracy: 0.7765 - lr: 1.0000e-04
# Epoch 81/90
# 74/74 [==============================] - 72s 985ms/step - loss: 0.2062 - accuracy: 0.9345 - val_loss: 0.8619 - val_accuracy: 0.7760 - lr: 1.0000e-04
# Epoch 82/90
# 74/74 [==============================] - 74s 1s/step - loss: 0.2063 - accuracy: 0.9356 - val_loss: 0.8624 - val_accuracy: 0.7755 - lr: 1.0000e-04
# Epoch 83/90
# 74/74 [==============================] - 74s 1s/step - loss: 0.2072 - accuracy: 0.9333 - val_loss: 0.8625 - val_accuracy: 0.7772 - lr: 1.0000e-04
# Epoch 84/90
# 74/74 [==============================] - 74s 1s/step - loss: 0.2131 - accuracy: 0.9332 - val_loss: 0.8629 - val_accuracy: 0.7760 - lr: 1.0000e-04
# Epoch 85/90
# 74/74 [==============================] - 73s 994ms/step - loss: 0.2036 - accuracy: 0.9345 - val_loss: 0.8652 - val_accuracy: 0.7760 - lr: 1.0000e-04
# Epoch 86/90
# 74/74 [==============================] - 74s 1s/step - loss: 0.2064 - accuracy: 0.9332 - val_loss: 0.8661 - val_accuracy: 0.7762 - lr: 1.0000e-04
# Epoch 87/90
# 74/74 [==============================] - 73s 1000ms/step - loss: 0.2050 - accuracy: 0.9363 - val_loss: 0.8644 - val_accuracy: 0.7760 - lr: 1.0000e-04
# Epoch 88/90
# 74/74 [==============================] - 74s 1s/step - loss: 0.2009 - accuracy: 0.9385 - val_loss: 0.8649 - val_accuracy: 0.7747 - lr: 1.0000e-04
# Epoch 89/90
# 74/74 [==============================] - 73s 996ms/step - loss: 0.1965 - accuracy: 0.9378 - val_loss: 0.8667 - val_accuracy: 0.7760 - lr: 1.0000e-04
# Epoch 90/90
# 72/74 [============================>.] - ETA: 1s - loss: 0.2067 - accuracy: 0.9325
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6660 batches). You may need to use the repeat() function when building your dataset.
# 74/74 [==============================] - 83s 1s/step - loss: 0.2067 - accuracy: 0.9325 - val_loss: 0.8643 - val_accuracy: 0.7762 - lr: 1.0000e-04

# %%
acc = hist.history["accuracy"]
val_acc = hist.history["val_accuracy"]

loss = hist.history["loss"]
val_loss = hist.history["val_loss"]

epochs = range(1, num_epochs + 1)
plt.plot(epochs, acc, "r.", label="Train acc")
plt.plot(epochs, val_acc, "g", label="Val acc")
plt.title("Train & val acc.")
plt.legend()
plt.figure()

plt.plot(epochs, loss, "r.", label="Train loss")
plt.plot(epochs, val_loss, "g", label="Val loss")
plt.title("Train & val loss")
plt.legend()
plt.show()
